# %% [markdown]
# # DWD SWSMOS Forecast Dashboard
#
# This notebook launches the SWSMOS (Road Weather Forecast) dashboard.
# It allows you to download forecast files (CSV) and visualize predictions for specific stations.

# %%
import sys
import os
from IPython.display import display

# Add src to path if running from notebooks dir and not installed
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', 'src')))

from dwd_sws import launch_swsmos

# %% [markdown]
# ## Launch SWSMOS Dashboard
#
# 1. **Select Forecast File**: Choose a timestamped file from the dropdown (defaults to latest).
# 2. **Load Forecast**: Click the button to download and parse the ~2MB file.
# 3. **Select Station**: Pick a station to see the forecast time series.

# %%
dashboard = launch_swsmos()
display(dashboard)
# Out:
# Loading station catalog...
# ...
